# %%
import pandas as pd
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import numpy as np
from scipy.stats import norm
from Data_scrapping import get_market_data_about_option_chain_for_computing_implied_volatility
from Computing_IV import get_Implied_volatility
from Graphs import plot_discount_curve, lines_3D, lines_3D_SVI_raw, lines_2D_SVI_raw, lines_3D_data_options, error_graph_3D, lines_2D_SVI, lines_2D_total_varience
from SVI_curves import computing_SVI_IV
from check_static_arbitrage import get_g_function_for_butterfly_arbitrage, check_butterflies_arbitrage_with_formula, check_calender_arbitrage, check_limit_price, check_static_arbitrage
from Computing_option_prices import get_data_about_option

# %%
# scrapping market data about option chain for specified tickers
# tickers_set = ['^SPX','AAPL','MSFT','NVDA','AVGO','ORCL', 'CSCO', 'CRM','TXN','ADBE','QCOM','INTC','IBM','AMZN','TSLA', 'HD','MCD','NKE','LOW', 'GOOG', 'META','TMUS','DIS','NFLX','VZ', 'CMCSA','T', 'XOM', 'CVX', 'COP', 'BRK-B', 'V', 'JPM', 'MA', 'BAC','WFC','SCHW','MS','UNH', 'JNJ', 'PFE', 'ABBV', 'MRK', 'TMO', 'ABT', 'BMY', 'CVS', 'WMT', 'PG', 'KO', 'PEP', 'COST', 'PM', 'UPS', 'RTX', 'HON', 'NEE']

# get_market_data_about_option_chain_for_computing_implied_volatility(tickers_set)

# %% [markdown]
# Download data about option chains from Yahoo Finance and discount curve as 3 - month SOFR Forward from Chatham Finance. Data about SOFR Forward curve for 1 and 3 month is available to this link: https://www.chathamfinancial.com/technology/us-forward-curves

# %%
ticker = 'AAPL'
data_date = "2023-05-18_23-46" #2023-05-12, 2023-05-16, 2023-05-17, 2023-05-18, 2023-05-19
filename_for_option_chain = "DATA\\Option_chain\\" + data_date + "\\" + ticker + ".csv"
filename_for_discount_curve = "DATA\\Discount_curve\\" + data_date + "\\Forward_SOFR_curve.xlsx"
options_data = pd.read_csv(filename_for_option_chain)
options_data = options_data.loc[pd.to_datetime(options_data['lastTradeDate']) > '2023-05-18 00:00:00'] # keep trades only in last date
discount_curve = pd.read_excel(filename_for_discount_curve)
plot_discount_curve(discount_curve, data_date)

# %%
expiry_date_list= options_data["expiryDate"].unique()
for expiry_date in expiry_date_list:
    options_at_given_expiry = options_data.loc[options_data["expiryDate"]==expiry_date]
    print("Number contracts expiring on", expiry_date, ":", len(options_at_given_expiry))
# Out:
# Number contracts expiring on 2023-05-19 : 34
# Number contracts expiring on 2023-05-26 : 45
# Number contracts expiring on 2023-06-02 : 32
# Number contracts expiring on 2023-06-09 : 30
# Number contracts expiring on 2023-06-16 : 49
# Number contracts expiring on 2023-06-23 : 29
# Number contracts expiring on 2023-06-30 : 26
# Number contracts expiring on 2023-07-21 : 45
# Number contracts expiring on 2023-08-18 : 50
# Number contracts expiring on 2023-09-15 : 54
# Number contracts expiring on 2023-10-20 : 47
# Number contracts expiring on 2023-11-17 : 39
# Number contracts expiring on 2023-12-15 : 49
# Number contracts expiring on 2024-01-19 : 72
# Number contracts expiring on 2024-03-15 : 53
# Number contracts expiring on 2024-06-21 : 67
# Number contracts expiring on 2024-09-20 : 39
# Number contracts expiring on 2024-12-20 : 31
# Number contracts expiring on 2025-01-17 : 66
# Number contracts expiring on 2025-06-20 : 43
# Number contracts expiring on 2025-12-19 : 54

# %% [markdown]
# Computing implied volatility by inverse solving Black-76 model respect to sigma, for given market option data.

# %%
Implied_Volatility = get_Implied_volatility(options_data, discount_curve)

# %%
# %timeit get_Implied_volatility(options_data, discount_curve)
# Out:
# 1.71 s ± 61 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Each lines on the graph is expiration date, points are the contracts on last trade date.
#
# X-line is forward moneyness - Strike / reference forward.
# Y-line - maturity in year fraction.
# Z-line - implied volatility

# %%
lines_3D(ticker, Implied_Volatility)

# %% [markdown]
# SVI Model (Stochastic volatility inspired) is some function that used to approximate the implied volatility curve. $x = ln(K/F_0)$ and $\omega = T\sigma^2$ - full implied variance
# $$\omega(x) = a + b \left(\rho(x - m) + \sqrt{(x-m)^2 + \sigma^2}\right)$$
# $a, b, \rho, m, \sigma$ - parameters, where $(a \in \mathbb{R}, b \geqslant 0, |\rho| < 1, m \in \mathbb{R}, \sigma > 0)$

# %%
Implied_Volatility_without_extrapolation = computing_SVI_IV(Implied_Volatility, ticker, low_limit = 0.1, high_limit = 2.5, N = 1000, extrapolation=False)

# %%
# %timeit computing_SVI_IV(Implied_Volatility, ticker, low_limit = 0.1, high_limit = 2.5, N = 1000, extrapolation=False)
# Out:
# 1min 21s ± 1.65 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# Parameter calibration is based on the algorithm implemented by Zhitlukhin M.V. Initial parameters for SVI calibration are calibrated SVI parameters from previous day. If the previous calibration is absence for specific expiration, use initial parameters from article "Robust Calibration For SVI Model Arbitrage Free" by Tahar Ferhati: $a = \frac{1}{2} min[w(x)], b = 0.1, rho -0.5, m = 0.1, sigma = 0.1$

# %%
Initial_parametres = pd.read_csv('DATA\\Initial_parametres_for_SVI_calibrator\\List_initial_parameters_for_SVI.csv', index_col='expiry_date')
Initial_parametres.loc[Initial_parametres['date'] == '2023-5-19']
# Out:
#                   date  2023-05-12  2023-05-19  2023-05-26  2023-06-02
# expiry_date
# a            2023-5-19         NaN         NaN   -0.007113   -0.043424  \
# b            2023-5-19         NaN         NaN    0.049266    0.118050
# rho          2023-5-19         NaN         NaN    0.021536    0.215818
# m            2023-5-19         NaN         NaN    0.013283    0.106330
# sigma        2023-5-19         NaN         NaN    0.154169    0.385821
#
#              2023-06-09  2023-06-16  2023-06-23  2023-07-21  2023-08-18  ...
# expiry_date                                                              ...
# a             -0.035964   -0.070081   -0.059005   -0.075423   -0.066598  ...  \
# b              0.178475    0.160207    0.127412    0.162956    0.169224  ...
# rho           -0.774424    0.286452    0.121120    0.237320    0.258785  ...
# m             -0.376660    0.193264    0.125765    0.228668    0.269546  ...
# sigma          0.338426    0.471313    0.488250    0.505673    0.457247  ...
#
#              2023-12-15  2024-01-19  2024-03-15  2024-06-21  2024-09-20
# expiry_date
# a             -0.081868   -0.140919   -0.101333   -0.383319   -0.160619  \
# b              0.187506    0.290735    0.178292    0.381930    0.264412
# rho            0.108780    0.375206   -0.103506    0.165353    0.095830
# m              0.342754    0.552194    0.332055    0.550795    0.505156
# sigma          0.548838    0.610714    0.739710    1.142790    0.830759
#
#              2024-12-20  2025-01-17  2025-06-20  2025-12-19  2023-06-30
# expiry_date
# a              0.026547   -0.774542    0.098517    0.115152   -0.018790
# b              0.192250    0.482214    0.088430    0.107897    0.083739
# rho            0.200654   -0.606717   -1.000000   -1.000000    0.042553
# m              0.429968   -0.892872    0.153363    0.083342    0.084153
# sigma          0.236068    2.199857    0.205689    0.382644    0.261843
#
# [5 rows x 23 columns]

# %% [markdown]
# Follow graphs show comparing implied volatility from SVI model and implied volatility given from Black-76 model for different expirations

# %%
lines_2D_SVI(ticker, Implied_Volatility_without_extrapolation,0)

# %%
lines_2D_SVI(ticker, Implied_Volatility_without_extrapolation,1)

# %%
lines_2D_SVI(ticker, Implied_Volatility_without_extrapolation,5)

# %%
lines_2D_SVI(ticker, Implied_Volatility_without_extrapolation,15)

# %%
lines_2D_SVI(ticker, Implied_Volatility_without_extrapolation,19)

# %% [markdown]
# ####  Calendar arbitrage
# $C(T_1,K) > C(T_2,K),\:for\:some\ T_1 < T_2\:and\:K > 0$
# Then we can get arbitrage by selling the option call $(T1;K)$ and buying the option call $(T2;K)$
#
# Calendar arbitrage is absence if and only if $\partial_t W(x,t) \geqslant 0$, where $W(x,t) -$ total implied varience, $x \in \mathbb{R}$
#
# It means that no one total variance curves aren't cross. Follow graph show this crosdering

# %%
lines_2D_total_varience(ticker, Implied_Volatility_without_extrapolation)

# %% [markdown]
# #### butterflies arbitrage:
# $C(T,K_1) + C(T,K_3) < 2C(T,K_2)$ ,some $ K_1 < K_2 < K_3 $ and $ T > 0$
#
# We can buy one call option $(T,K_1)$ and one $(T,K_3)$ and sell two call option $(T,K_2)$ Butterflies arbitrage is absence if and only if g-function from "Arbitrage-free SVI volatility surfaces" by
# Jim Gatheral and Antoine Jacquiery is positive
#
# g-function:  $g(x) := \left(1 - \frac{xw'(x)}{2w(x)}\right)^2 - \frac{w'(x)^2}{4} \left(\frac{1}{w(x)} + \frac{1}{4}\right) + \frac{w''(x)}{2}$

# %%
g_k = get_g_function_for_butterfly_arbitrage(Implied_Volatility_without_extrapolation, 10, graph=True, N=1000, right_limit = 3)

# %% [markdown]
# Follow have shown computing option prices via implied volatility from SVI model and comparing them with initial bid ask spread. Error graph shows that option prices within bid ask spread, grey is inside bid ask spread, above means higher, below means lower.

# %%
value_options = get_data_about_option(Implied_Volatility_without_extrapolation, filename_for_option_chain, optionTypes=None, amount_options=None) # Only for those strikes for which contracts were traded on the last trade day

# %%
# %timeit get_data_about_option(Implied_Volatility_without_extrapolation, filename_for_option_chain, optionTypes=None, amount_options=None)
# Out:
# 1.13 s ± 1.97 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
print('number options for all curves inside of bid ask spread =', len(value_options.loc[value_options['correct_price'] == 'inside']) / len(value_options) * 100, '%')
print('number options for all curves strikes above of bid ask spread =', len(value_options.loc[value_options['correct_price'] == 'above']) / len(value_options) * 100, '%')
print('number options for all curves strikes below of bid ask spread =', len(value_options.loc[value_options['correct_price'] == 'below']) / len(value_options) * 100, '%')
# Out:
# number options for all curves inside of bid ask spread = 69.62750716332378 %
# number options for all curves strikes above of bid ask spread = 21.872015281757403 %
# number options for all curves strikes below of bid ask spread = 8.500477554918815 %

# %%
error_graph_3D(value_options, ticker, type_option='ITM')

# %%
error_graph_3D(value_options, ticker, type_option='OTM')

# %% [markdown]
# Checking the static arbitrage for given curves

# %%
check_static_arbitrage(value_options, Implied_Volatility_without_extrapolation)
# Out:
# butterfly arbitrage exists

# %%
calender_arbitrage = check_calender_arbitrage(value_options)
if calender_arbitrage.empty:
    print('calender arbitrage is absence')
else:
    print('calender arbitrage exists')
# Out:
# calender arbitrage is absence

# %%
calender_arbitrage
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# only OTM options
for expiry_date in value_options['expiry_date'].unique():
    value_options_check  = value_options.loc[(value_options['expiry_date'] == expiry_date)]
    value_options_check = value_options_check.loc[((value_options_check["x_grid"] >= 1) & (value_options_check["optionType"] == "calls")) | ((value_options_check["x_grid"] < 1) & (value_options_check["optionType"] == 'puts'))]
    print('number options within bid ask spread for only OTM options on', expiry_date, ' =', len(value_options_check.loc[(value_options_check['correct_price'] == 'inside')]) / len(value_options_check) * 100, '%')
# Out:
# number options within bid ask spread for only OTM options on 2023-05-26  = 68.0 %
# number options within bid ask spread for only OTM options on 2023-06-02  = 75.0 %
# number options within bid ask spread for only OTM options on 2023-06-09  = 63.1578947368421 %
# number options within bid ask spread for only OTM options on 2023-06-16  = 78.26086956521739 %
# number options within bid ask spread for only OTM options on 2023-06-23  = 66.66666666666666 %
# number options within bid ask spread for only OTM options on 2023-06-30  = 58.82352941176471 %
# number options within bid ask spread for only OTM options on 2023-07-21  = 60.71428571428571 %
# number options within bid ask spread for only OTM options on 2023-08-18  = 60.0 %
# number options within bid ask spread for only OTM options on 2023-09-15  = 61.76470588235294 %
# number options within bid ask spread for only OTM options on 2023-10-20  = 75.75757575757575 %
# number options within bid ask spread for only OTM options on 2023-11-17  = 64.70588235294117 %
# number options within bid ask spread for only OTM options on 2023-12-15  = 77.77777777777779 %
# number options within bid ask spread for only OTM options on 2024-01-19  = 82.6923076923077 %
# number options within bid ask spread for only OTM options on 2024-03-15  = 100.0 %
# number options within bid ask spread for only OTM options on 2024-06-21  = 100.0 %
# number options within bid ask spread for only OTM options on 2024-09-20  = 94.44444444444444 %
# number options within bid ask spread for only OTM options on 2024-12-20  = 100.0 %
# number options within bid ask spread for only OTM options on 2025-01-17  = 100.0 %
# number options within bid ask spread for only OTM options on 2025-06-20  = 90.32258064516128 %
# number options within bid ask spread for only OTM options on 2025-12-19  = 95.23809523809523 %

# %%
# for all options
for expiry_date in value_options['expiry_date'].unique():
    print('number options within bid ask spread for all options on', expiry_date, '=', len(value_options.loc[(value_options['expiry_date'] == expiry_date) & (value_options['correct_price'] == 'inside')]) / len(value_options.loc[(value_options['expiry_date'] == expiry_date)]) * 100, '%')
# Out:
# number options within bid ask spread for all options on 2023-05-26 = 79.59183673469387 %
# number options within bid ask spread for all options on 2023-06-02 = 81.25 %
# number options within bid ask spread for all options on 2023-06-09 = 70.96774193548387 %
# number options within bid ask spread for all options on 2023-06-16 = 78.43137254901961 %
# number options within bid ask spread for all options on 2023-06-23 = 72.72727272727273 %
# number options within bid ask spread for all options on 2023-06-30 = 66.66666666666666 %
# number options within bid ask spread for all options on 2023-07-21 = 52.0 %
# number options within bid ask spread for all options on 2023-08-18 = 52.72727272727272 %
# number options within bid ask spread for all options on 2023-09-15 = 49.152542372881356 %
# number options within bid ask spread for all options on 2023-10-20 = 62.264150943396224 %
# number options within bid ask spread for all options on 2023-11-17 = 60.78431372549019 %
# number options within bid ask spread for all options on 2023-12-15 = 72.22222222222221 %
# number options within bid ask spread for all options on 2024-01-19 = 63.29113924050633 %
# number options within bid ask spread for all options on 2024-03-15 = 81.9672131147541 %
# number options within bid ask spread for all options on 2024-06-21 = 65.82278481012658 %
# number options within bid ask spread for all options on 2024-09-20 = 82.6923076923077 %
# number options within bid ask spread for all options on 2024-12-20 = 88.09523809523809 %
# number options within bid ask spread for all options on 2025-01-17 = 77.46478873239437 %
# number options within bid ask spread for all options on 2025-06-20 = 73.58490566037736 %
# number options within bid ask spread for all options on 2025-12-19 = 72.3076923076923 %

# %%
value_options = get_data_about_option(Implied_Volatility_without_extrapolation, filename_for_option_chain, optionTypes=None, amount_options='All') # for all listed strikes

# %%
print('number options for all curves for all listed strikes inside of bid ask spread =', len(value_options.loc[value_options['correct_price'] == 'inside']) / len(value_options) * 100, '%')
print('number options for all curves for all listed strikes above of bid ask spread =', len(value_options.loc[value_options['correct_price'] == 'above']) / len(value_options) * 100, '%')
print('number options for all curves for all listed strikes below of bid ask spread =', len(value_options.loc[value_options['correct_price'] == 'below']) / len(value_options) * 100, '%')
# Out:
# number options for all curves for all listed strikes inside of bid ask spread = 59.25423728813559 %
# number options for all curves for all listed strikes above of bid ask spread = 24.06779661016949 %
# number options for all curves for all listed strikes below of bid ask spread = 16.677966101694917 %

# %%
error_graph_3D(value_options, ticker, type_option='ITM')

# %%
error_graph_3D(value_options, ticker, type_option='OTM')

# %%
check_static_arbitrage(value_options, Implied_Volatility_without_extrapolation)
# Out:
# calander arbitrage exists
# butterfly arbitrage exists

# %%
calender_arbitrage = check_calender_arbitrage(value_options)
if calender_arbitrage.empty:
    print('calender arbitrage is absence')
else:
    print('calender arbitrage exists')
# Out:
# calender arbitrage exists

# %%
calender_arbitrage
# Out:
#      x_grid        IV value_option expiry_date
# 0  1.350656  0.195182    62.333212  2023-09-15  \
# 0  1.332482  0.188682    60.281204  2024-01-19
# 0  1.650615  0.607364   114.323436  2023-06-16
# 0  1.632043  0.273066   112.316728  2023-09-15
# 0  1.707532   0.64652   124.324197  2023-06-16
# 0   1.68832  0.290237   122.316801  2023-09-15
# 0   1.38781  0.264114    68.471993  2023-07-21
# 0  1.360242  0.188624    65.166801  2024-01-19
#
#   expiry_date_in_act365_year_fraction optionType strike     bid     ask
# 0                            0.326027       puts  240.0    63.6    65.8  \
# 0                            0.671233       puts  240.0    87.1   87.75
# 0                            0.076712       puts  290.0  154.85  155.95
# 0                            0.326027       puts  290.0  146.85   148.7
# 0                            0.076712       puts  300.0  140.05  142.05
# 0                            0.326027       puts  300.0  123.85   125.4
# 0                            0.172603       puts  245.0  109.55  110.15
# 0                            0.671233       puts  245.0    88.3   91.15
#
#   correct_price
# 0         below
# 0         below
# 0         below
# 0         below
# 0         below
# 0         below
# 0         below
# 0         below

# %%
# only OTM options
for expiry_date in value_options['expiry_date'].unique():
    value_options_check  = value_options.loc[(value_options['expiry_date'] == expiry_date)]
    value_options_check = value_options_check.loc[((value_options_check["x_grid"] >= 1) & (value_options_check["optionType"] == "calls")) | ((value_options_check["x_grid"] < 1) & (value_options_check["optionType"] == 'puts'))]
    print('number options within bid ask spread for only OTM options for all listed strikes on', expiry_date, ' =', len(value_options_check.loc[(value_options_check['correct_price'] == 'inside')]) / len(value_options_check) * 100, '%')
# Out:
# number options within bid ask spread for only OTM options for all listed strikes on 2023-05-26  = 68.0 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-06-02  = 75.0 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-06-09  = 63.1578947368421 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-06-16  = 78.26086956521739 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-06-23  = 69.56521739130434 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-06-30  = 60.0 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-07-21  = 60.0 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-08-18  = 61.111111111111114 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-09-15  = 61.76470588235294 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-10-20  = 74.4186046511628 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-11-17  = 60.86956521739131 %
# number options within bid ask spread for only OTM options for all listed strikes on 2023-12-15  = 65.21739130434783 %
# number options within bid ask spread for only OTM options for all listed strikes on 2024-01-19  = 82.6923076923077 %
# number options within bid ask spread for only OTM options for all listed strikes on 2024-03-15  = 95.65217391304348 %
# number options within bid ask spread for only OTM options for all listed strikes on 2024-06-21  = 98.07692307692307 %
# number options within bid ask spread for only OTM options for all listed strikes on 2024-09-20  = 93.87755102040816 %
# number options within bid ask spread for only OTM options for all listed strikes on 2024-12-20  = 100.0 %
# number options within bid ask spread for only OTM options for all listed strikes on 2025-01-17  = 100.0 %
# number options within bid ask spread for only OTM options for all listed strikes on 2025-06-20  = 91.48936170212765 %
# number options within bid ask spread for only OTM options for all listed strikes on 2025-12-19  = 95.74468085106383 %

# %%
for expiry_date in value_options['expiry_date'].unique():
    print('number options within bid ask spread for all options for all listed strikes on',expiry_date, '=', len(value_options.loc[(value_options['expiry_date'] == expiry_date) & (value_options['correct_price'] == 'inside')]) / len(value_options.loc[(value_options['expiry_date'] == expiry_date)]) * 100, '%')
# Out:
# number options within bid ask spread for all options for all listed strikes on 2023-05-26 = 82.45614035087719 %
# number options within bid ask spread for all options for all listed strikes on 2023-06-02 = 82.05128205128204 %
# number options within bid ask spread for all options for all listed strikes on 2023-06-09 = 75.67567567567568 %
# number options within bid ask spread for all options for all listed strikes on 2023-06-16 = 68.75 %
# number options within bid ask spread for all options for all listed strikes on 2023-06-23 = 78.04878048780488 %
# number options within bid ask spread for all options for all listed strikes on 2023-06-30 = 66.66666666666666 %
# number options within bid ask spread for all options for all listed strikes on 2023-07-21 = 43.83561643835616 %
# number options within bid ask spread for all options for all listed strikes on 2023-08-18 = 41.66666666666667 %
# number options within bid ask spread for all options for all listed strikes on 2023-09-15 = 39.726027397260275 %
# number options within bid ask spread for all options for all listed strikes on 2023-10-20 = 49.382716049382715 %
# number options within bid ask spread for all options for all listed strikes on 2023-11-17 = 50.68493150684932 %
# number options within bid ask spread for all options for all listed strikes on 2023-12-15 = 49.411764705882355 %
# number options within bid ask spread for all options for all listed strikes on 2024-01-19 = 48.07692307692308 %
# number options within bid ask spread for all options for all listed strikes on 2024-03-15 = 60.43956043956044 %
# number options within bid ask spread for all options for all listed strikes on 2024-06-21 = 57.42574257425742 %
# number options within bid ask spread for all options for all listed strikes on 2024-09-20 = 67.05882352941175 %
# number options within bid ask spread for all options for all listed strikes on 2024-12-20 = 74.4186046511628 %
# number options within bid ask spread for all options for all listed strikes on 2025-01-17 = 60.78431372549019 %
# number options within bid ask spread for all options for all listed strikes on 2025-06-20 = 65.9090909090909 %
# number options within bid ask spread for all options for all listed strikes on 2025-12-19 = 61.29032258064516 %

# %%
for i, expiry_date in enumerate(value_options['expiry_date'].unique()):
    k = value_options.loc[value_options['expiry_date'] == expiry_date]
    print('nubmer contracts within bid ask on', expiry_date, '=', len(k.loc[k['correct_price'] == 'inside']) / len(k) * 100, '%')
    print('nubmer contracts on', expiry_date, '=', len(k))
    print('reference_forward = ', Implied_Volatility['implied_volatility_surface'][i]['reference_forward'])
    print('Time = ', Implied_Volatility['implied_volatility_surface'][i]['expiry_date_in_act365_year_fraction'])
    print('discount factor =', Implied_Volatility['implied_volatility_surface'][i]['reference_discount_factor'])
    below = k.loc[k['correct_price'] == 'below']
    above = k.loc[k['correct_price'] == 'above']
    print('mean relative error for options below bid ask spread on', expiry_date,'=', ((below.bid - below.value_option) / below.bid).mean() * 100, '%')
    print('mean relative error for options above bid ask spread on', expiry_date,'=', ((above.value_option - above.ask) / above.ask).mean() * 100, '%')
    print()
# Out:
# nubmer contracts within bid ask on 2023-05-26 = 82.45614035087719 %
# nubmer contracts on 2023-05-26 = 57
# reference_forward =  175.26822956965998
# Time =  0.019178082191780823
# discount factor = 1.0043687266905388
# mean relative error for options below bid ask spread on 2023-05-26 = 3.8477022498696187 %
# mean relative error for options above bid ask spread on 2023-05-26 = 5.244344029416617 %
#
# nubmer contracts within bid ask on 2023-06-02 = 82.05128205128204 %
# nubmer contracts on 2023-06-02 = 39
# reference_forward =  175.36320553396587
# Time =  0.038356164383561646
# discount factor = 1.0043687266905388
# mean relative error for options below bid ask spread on 2023-06-02 = 3.2015117839158567 %
# mean relative error for options above bid ask spread on 2023-06-02 = 6.062045379410966 %
#
# nubmer contracts within bid ask on 2023-06-09 = 75.67567567567568 %
# nubmer contracts on 2023-06-09 = 37
# reference_forward =  175.5264154520531
# Time =  0.057534246575342465
# discount factor = 1.0043687266905388
# mean relative error for options below bid ask spread on 2023-06-09 = 2.373725255858846 %
# mean relative error for options above bid ask spread on 2023-06-09 = 4.805417247478216 %
#
# nubmer contracts within bid ask on 2023-06-16 = 68.75 %
# nubmer contracts on 2023-06-16 = 64
# reference_forward =  175.692136291957
# Time =  0.07671232876712329
# discount factor = 1.0043687266905388
# mean relative error for options below bid ask spread on 2023-06-16 = 9.79225567339869 %
# mean relative error for options above bid ask spread on 2023-06-16 = 7.202735076988255 %
#
# nubmer contracts within bid ask on 2023-06-23 = 78.04878048780488 %
# nubmer contracts on 2023-06-23 = 41
# reference_forward =  175.87269817852354
# Time =  0.0958904109589041
# discount factor = 1.0091794241714398
# mean relative error for options below bid ask spread on 2023-06-23 = 0.805415861234617 %
# mean relative error for options above bid ask spread on 2023-06-23 = 2.877184811445847 %
#
# nubmer contracts within bid ask on 2023-06-30 = 66.66666666666666 %
# nubmer contracts on 2023-06-30 = 30
# reference_forward =  176.01000115010856
# Time =  0.11506849315068493
# discount factor = 1.0101687117908125
# mean relative error for options below bid ask spread on 2023-06-30 = 4.151467500703856 %
# mean relative error for options above bid ask spread on 2023-06-30 = 1.6022390851114559 %
#
# nubmer contracts within bid ask on 2023-07-21 = 43.83561643835616 %
# nubmer contracts on 2023-07-21 = 73
# reference_forward =  176.53713374347353
# Time =  0.1726027397260274
# discount factor = 1.0135434279226048
# mean relative error for options below bid ask spread on 2023-07-21 = 9.435559067470427 %
# mean relative error for options above bid ask spread on 2023-07-21 = 2.795741566439956 %
#
# nubmer contracts within bid ask on 2023-08-18 = 41.66666666666667 %
# nubmer contracts on 2023-08-18 = 72
# reference_forward =  177.04215612719247
# Time =  0.2493150684931507
# discount factor = 1.0174308284611926
# mean relative error for options below bid ask spread on 2023-08-18 = 3.0995938641767795 %
# mean relative error for options above bid ask spread on 2023-08-18 = 2.5413208146489428 %
#
# nubmer contracts within bid ask on 2023-09-15 = 39.726027397260275 %
# nubmer contracts on 2023-09-15 = 73
# reference_forward =  177.69138045775975
# Time =  0.32602739726027397
# discount factor = 1.020695774718628
# mean relative error for options below bid ask spread on 2023-09-15 = 9.6552356854715 %
# mean relative error for options above bid ask spread on 2023-09-15 = 1.3744528690552584 %
#
# nubmer contracts within bid ask on 2023-10-20 = 49.382716049382715 %
# nubmer contracts on 2023-10-20 = 81
# reference_forward =  178.4615928437
# Time =  0.42191780821917807
# discount factor = 1.025699033280012
# mean relative error for options below bid ask spread on 2023-10-20 = 9.960538190280772 %
# mean relative error for options above bid ask spread on 2023-10-20 = 2.0841922358553924 %
#
# nubmer contracts within bid ask on 2023-11-17 = 50.68493150684932 %
# nubmer contracts on 2023-11-17 = 73
# reference_forward =  178.96675403464252
# Time =  0.4986301369863014
# discount factor = 1.0293010769421056
# mean relative error for options below bid ask spread on 2023-11-17 = 10.987010488945623 %
# mean relative error for options above bid ask spread on 2023-11-17 = 2.0664411999480734 %
#
# nubmer contracts within bid ask on 2023-12-15 = 49.411764705882355 %
# nubmer contracts on 2023-12-15 = 85
# reference_forward =  179.26070052179705
# Time =  0.5753424657534246
# discount factor = 1.03244604882962
# mean relative error for options below bid ask spread on 2023-12-15 = 12.704501661398709 %
# mean relative error for options above bid ask spread on 2023-12-15 = 1.7447943121786773 %
#
# nubmer contracts within bid ask on 2024-01-19 = 48.07692307692308 %
# nubmer contracts on 2024-01-19 = 104
# reference_forward =  180.1149939755013
# Time =  0.6712328767123288
# discount factor = 1.0369591410863788
# mean relative error for options below bid ask spread on 2024-01-19 = 9.71763723240212 %
# mean relative error for options above bid ask spread on 2024-01-19 = 1.4496317162523764 %
#
# nubmer contracts within bid ask on 2024-03-15 = 60.43956043956044 %
# nubmer contracts on 2024-03-15 = 91
# reference_forward =  180.98734676087363
# Time =  0.8246575342465754
# discount factor = 1.043209130431972
# mean relative error for options below bid ask spread on 2024-03-15 = 19.143667552811515 %
# mean relative error for options above bid ask spread on 2024-03-15 = 1.9728082797137856 %
#
# nubmer contracts within bid ask on 2024-06-21 = 57.42574257425742 %
# nubmer contracts on 2024-06-21 = 101
# reference_forward =  182.82925557114754
# Time =  1.093150684931507
# discount factor = 1.053617827672162
# mean relative error for options below bid ask spread on 2024-06-21 = 10.481385510147286 %
# mean relative error for options above bid ask spread on 2024-06-21 = 2.4695474167106397 %
#
# nubmer contracts within bid ask on 2024-09-20 = 67.05882352941175 %
# nubmer contracts on 2024-09-20 = 85
# reference_forward =  183.63515418158042
# Time =  1.3424657534246576
# discount factor = 1.0625005686376876
# mean relative error for options below bid ask spread on 2024-09-20 = 19.746660407195797 %
# mean relative error for options above bid ask spread on 2024-09-20 = 4.690975908632225 %
#
# nubmer contracts within bid ask on 2024-12-20 = 74.4186046511628 %
# nubmer contracts on 2024-12-20 = 86
# reference_forward =  184.98195227769313
# Time =  1.5917808219178082
# discount factor = 1.0705168474254676
# mean relative error for options below bid ask spread on 2024-12-20 = 12.588626726451741 %
# mean relative error for options above bid ask spread on 2024-12-20 = 3.595319416887392 %
#
# nubmer contracts within bid ask on 2025-01-17 = 60.78431372549019 %
# nubmer contracts on 2025-01-17 = 102
# reference_forward =  185.26823019154318
# Time =  1.6684931506849314
# discount factor = 1.0729207661727846
# mean relative error for options below bid ask spread on 2025-01-17 = 16.546154948574614 %
# mean relative error for options above bid ask spread on 2025-01-17 = 3.0191541103021904 %
#
# nubmer contracts within bid ask on 2025-06-20 = 65.9090909090909 %
# nubmer contracts on 2025-06-20 = 88
# reference_forward =  186.54898956893203
# Time =  2.0904109589041098
# discount factor = 1.085853516130614
# mean relative error for options below bid ask spread on 2025-06-20 = 5.037095883631661 %
# mean relative error for options above bid ask spread on 2025-06-20 = 3.4010996748438487 %
#
# nubmer contracts within bid ask on 2025-12-19 = 61.29032258064516 %
# nubmer contracts on 2025-12-19 = 93
# reference_forward =  189.74743044137455
# Time =  2.589041095890411
# discount factor = 1.1010278234501794
# mean relative error for options below bid ask spread on 2025-12-19 = 3.9617739028291687 %
# mean relative error for options above bid ask spread on 2025-12-19 = 4.925421608063087 %
